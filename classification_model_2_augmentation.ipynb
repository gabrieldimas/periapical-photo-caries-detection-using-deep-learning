# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrieldimas/periapical-photo-caries-detection-using-deep-learning/blob/main/classification_model_2_augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Extract Dataset, Import Section

# %%
import zipfile
import os

zip_path = "/content/segmented_teeth_v5_test1.zip"
extract_to = "/content/dataset"

os.makedirs(extract_to, exist_ok=True)
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to)

print(f"File berhasil diekstrak ke: {extract_to}")
# Out:
# File berhasil diekstrak ke: /content/dataset

# %%
# !pip install ultralytics

from ultralytics import YOLO
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 28.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 124.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 86.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 66.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 44.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %% [markdown]
# # Training with Rotation, Flipping

# %%
model = YOLO('yolov8n-cls.pt')
model.train(
    data="/content/dataset",
    epochs=100,
    imgsz=320,
    batch=16,
    augment=True,
    degrees=30,
    fliplr=0.5,
    flipud=0.5,
    scale=0,
    shear=0,
    translate=0
)
# Out:
# Ultralytics 8.3.131 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
metrics = model.val(data='/content/dataset')
print(metrics)
# Out:
# Ultralytics 8.3.131 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n-cls summary (fused): 30 layers, 1,438,723 parameters, 0 gradients, 3.3 GFLOPs
# train: /content/dataset/train... found 428 images in 3 classes ✅
# val: /content/dataset/val... found 52 images in 3 classes ✅
# test: /content/dataset/test... found 56 images in 3 classes ✅
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 292.9±287.1 MB/s, size: 14.8 KB)
# val: Scanning /content/dataset/val... 52 images, 0 corrupt: 100%|██████████| 52/52 [00:00<?, ?it/s]
#                classes   top1_acc   top5_acc:   0%|          | 0/4 [00:00<?, ?it/s]
# WARNING ⚠️ ClassificationModel does not support 'augment=True' prediction. Reverting to single-scale prediction.
#                classes   top1_acc   top5_acc:  25%|██▌       | 1/4 [00:00<00:00,  3.76it/s]
# WARNING ⚠️ ClassificationModel does not support 'augment=True' prediction. Reverting to single-scale prediction.
# ...

# %% [markdown]
# # Training with Rotation, Scaling

# %%
model = YOLO('yolov8n-cls.pt')
model.train(
    data="/content/dataset",
    epochs=100,
    imgsz=320,
    batch=16,
    augment=True,
    degrees=30,
    fliplr=0,
    flipud=0,
    scale=0.3,
    shear=0,
    translate=0
)
# Out:
# Ultralytics 8.3.131 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
metrics = model.val(data='/content/dataset')
print(metrics)
# Out:
# Ultralytics 8.3.131 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n-cls summary (fused): 30 layers, 1,438,723 parameters, 0 gradients, 3.3 GFLOPs
# train: /content/dataset/train... found 428 images in 3 classes ✅
# val: /content/dataset/val... found 52 images in 3 classes ✅
# test: /content/dataset/test... found 56 images in 3 classes ✅
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 219.9±190.4 MB/s, size: 14.8 KB)
# val: Scanning /content/dataset/val... 52 images, 0 corrupt: 100%|██████████| 52/52 [00:00<?, ?it/s]
#                classes   top1_acc   top5_acc:   0%|          | 0/4 [00:00<?, ?it/s]
# WARNING ⚠️ ClassificationModel does not support 'augment=True' prediction. Reverting to single-scale prediction.
#                classes   top1_acc   top5_acc:  25%|██▌       | 1/4 [00:00<00:00,  4.07it/s]
# WARNING ⚠️ ClassificationModel does not support 'augment=True' prediction. Reverting to single-scale prediction.
# ...

# %% [markdown]
# # Training with Rotation, Shearing

# %%
model = YOLO('yolov8n-cls.pt')
model.train(
    data="/content/dataset",
    epochs=100,
    imgsz=320,
    batch=16,
    augment=True,
    degrees=30,
    fliplr=0,
    flipud=0,
    scale=0,
    shear=5,
    translate=0
)
# Out:
# Ultralytics 8.3.131 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
metrics = model.val(data='/content/dataset')
print(metrics)
# Out:
# Ultralytics 8.3.131 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n-cls summary (fused): 30 layers, 1,438,723 parameters, 0 gradients, 3.3 GFLOPs
# train: /content/dataset/train... found 428 images in 3 classes ✅
# val: /content/dataset/val... found 52 images in 3 classes ✅
# test: /content/dataset/test... found 56 images in 3 classes ✅
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 295.0±272.0 MB/s, size: 14.8 KB)
# val: Scanning /content/dataset/val... 52 images, 0 corrupt: 100%|██████████| 52/52 [00:00<?, ?it/s]
#                classes   top1_acc   top5_acc:   0%|          | 0/4 [00:00<?, ?it/s]
# WARNING ⚠️ ClassificationModel does not support 'augment=True' prediction. Reverting to single-scale prediction.
#                classes   top1_acc   top5_acc:  25%|██▌       | 1/4 [00:00<00:00,  3.39it/s]
# WARNING ⚠️ ClassificationModel does not support 'augment=True' prediction. Reverting to single-scale prediction.
# ...

# %% [markdown]
# # Training with Rotation, Translation

# %%
model = YOLO('yolov8n-cls.pt')
model.train(
    data="/content/dataset",
    epochs=100,
    imgsz=320,
    batch=16,
    augment=True,
    degrees=30,
    fliplr=0,
    flipud=0,
    scale=0,
    shear=0,
    translate=0.2
)
# Out:
# Ultralytics 8.3.131 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
metrics = model.val(data='/content/dataset')
print(metrics)
# Out:
# Ultralytics 8.3.131 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n-cls summary (fused): 30 layers, 1,438,723 parameters, 0 gradients, 3.3 GFLOPs
# train: /content/dataset/train... found 428 images in 3 classes ✅
# val: /content/dataset/val... found 52 images in 3 classes ✅
# test: /content/dataset/test... found 56 images in 3 classes ✅
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 293.4±278.6 MB/s, size: 14.8 KB)
# val: Scanning /content/dataset/val... 52 images, 0 corrupt: 100%|██████████| 52/52 [00:00<?, ?it/s]
#                classes   top1_acc   top5_acc:   0%|          | 0/4 [00:00<?, ?it/s]
# WARNING ⚠️ ClassificationModel does not support 'augment=True' prediction. Reverting to single-scale prediction.
#                classes   top1_acc   top5_acc:  25%|██▌       | 1/4 [00:00<00:00,  4.13it/s]
# WARNING ⚠️ ClassificationModel does not support 'augment=True' prediction. Reverting to single-scale prediction.
# ...

# %% [markdown]
# # Training with Flipping, Scaling

# %%
model = YOLO('yolov8n-cls.pt')
model.train(
    data="/content/dataset",
    epochs=100,
    imgsz=320,
    batch=16,
    augment=True,
    degrees=0,
    fliplr=0.5,
    flipud=0.5,
    scale=0.3,
    shear=0,
    translate=0
)
# Out:
# Ultralytics 8.3.131 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
metrics = model.val(data='/content/dataset')
print(metrics)
# Out:
# Ultralytics 8.3.131 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n-cls summary (fused): 30 layers, 1,438,723 parameters, 0 gradients, 3.3 GFLOPs
# train: /content/dataset/train... found 428 images in 3 classes ✅
# val: /content/dataset/val... found 52 images in 3 classes ✅
# test: /content/dataset/test... found 56 images in 3 classes ✅
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 268.0±280.1 MB/s, size: 14.8 KB)
# val: Scanning /content/dataset/val... 52 images, 0 corrupt: 100%|██████████| 52/52 [00:00<?, ?it/s]
#                classes   top1_acc   top5_acc:   0%|          | 0/4 [00:00<?, ?it/s]
# WARNING ⚠️ ClassificationModel does not support 'augment=True' prediction. Reverting to single-scale prediction.
#                classes   top1_acc   top5_acc:  25%|██▌       | 1/4 [00:00<00:00,  4.74it/s]
# WARNING ⚠️ ClassificationModel does not support 'augment=True' prediction. Reverting to single-scale prediction.
# ...

# %% [markdown]
# # Training with Flipping, Shearing

# %%
model = YOLO('yolov8n-cls.pt')
model.train(
    data="/content/dataset",
    epochs=100,
    imgsz=320,
    batch=16,
    augment=True,
    degrees=0,
    fliplr=0.5,
    flipud=0.5,
    scale=0,
    shear=5,
    translate=0
)
# Out:
# Ultralytics 8.3.131 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
metrics = model.val(data='/content/dataset')
print(metrics)
# Out:
# Ultralytics 8.3.131 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n-cls summary (fused): 30 layers, 1,438,723 parameters, 0 gradients, 3.3 GFLOPs
# train: /content/dataset/train... found 428 images in 3 classes ✅
# val: /content/dataset/val... found 52 images in 3 classes ✅
# test: /content/dataset/test... found 56 images in 3 classes ✅
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 263.2±265.4 MB/s, size: 14.8 KB)
# val: Scanning /content/dataset/val... 52 images, 0 corrupt: 100%|██████████| 52/52 [00:00<?, ?it/s]
#                classes   top1_acc   top5_acc:   0%|          | 0/4 [00:00<?, ?it/s]
# WARNING ⚠️ ClassificationModel does not support 'augment=True' prediction. Reverting to single-scale prediction.
#                classes   top1_acc   top5_acc:  25%|██▌       | 1/4 [00:00<00:00,  3.66it/s]
# WARNING ⚠️ ClassificationModel does not support 'augment=True' prediction. Reverting to single-scale prediction.
# ...

# %% [markdown]
# # Training with Flipping, Translation

# %%
model = YOLO('yolov8n-cls.pt')
model.train(
    data="/content/dataset",
    epochs=100,
    imgsz=320,
    batch=16,
    augment=True,
    degrees=0,
    fliplr=0.5,
    flipud=0.5,
    scale=0,
    shear=0,
    translate=0.2
)
# Out:
# Ultralytics 8.3.131 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
metrics = model.val(data='/content/dataset')
print(metrics)
# Out:
# Ultralytics 8.3.131 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n-cls summary (fused): 30 layers, 1,438,723 parameters, 0 gradients, 3.3 GFLOPs
# train: /content/dataset/train... found 428 images in 3 classes ✅
# val: /content/dataset/val... found 52 images in 3 classes ✅
# test: /content/dataset/test... found 56 images in 3 classes ✅
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 255.9±299.5 MB/s, size: 14.8 KB)
# val: Scanning /content/dataset/val... 52 images, 0 corrupt: 100%|██████████| 52/52 [00:00<?, ?it/s]
#                classes   top1_acc   top5_acc:   0%|          | 0/4 [00:00<?, ?it/s]
# WARNING ⚠️ ClassificationModel does not support 'augment=True' prediction. Reverting to single-scale prediction.
#                classes   top1_acc   top5_acc:  25%|██▌       | 1/4 [00:00<00:00,  4.08it/s]
# WARNING ⚠️ ClassificationModel does not support 'augment=True' prediction. Reverting to single-scale prediction.
# ...

# %% [markdown]
# # Training with Scaling, Shearing

# %%
model = YOLO('yolov8n-cls.pt')
model.train(
    data="/content/dataset",
    epochs=100,
    imgsz=320,
    batch=16,
    augment=True,
    degrees=0,
    fliplr=0,
    flipud=0,
    scale=0.3,
    shear=5,
    translate=0
)
# Out:
# Ultralytics 8.3.131 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
metrics = model.val(data='/content/dataset')
print(metrics)
# Out:
# Ultralytics 8.3.131 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n-cls summary (fused): 30 layers, 1,438,723 parameters, 0 gradients, 3.3 GFLOPs
# train: /content/dataset/train... found 428 images in 3 classes ✅
# val: /content/dataset/val... found 52 images in 3 classes ✅
# test: /content/dataset/test... found 56 images in 3 classes ✅
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 271.8±263.4 MB/s, size: 14.8 KB)
# val: Scanning /content/dataset/val... 52 images, 0 corrupt: 100%|██████████| 52/52 [00:00<?, ?it/s]
#                classes   top1_acc   top5_acc:   0%|          | 0/4 [00:00<?, ?it/s]
# WARNING ⚠️ ClassificationModel does not support 'augment=True' prediction. Reverting to single-scale prediction.
#                classes   top1_acc   top5_acc:  25%|██▌       | 1/4 [00:00<00:00,  3.69it/s]
# WARNING ⚠️ ClassificationModel does not support 'augment=True' prediction. Reverting to single-scale prediction.
# ...

# %% [markdown]
# # Training with Scaling, Translation

# %%
model = YOLO('yolov8n-cls.pt')
model.train(
    data="/content/dataset",
    epochs=100,
    imgsz=320,
    batch=16,
    augment=True,
    degrees=0,
    fliplr=0,
    flipud=0,
    scale=0.3,
    shear=0,
    translate=0.2
)
# Out:
# Ultralytics 8.3.131 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
metrics = model.val(data='/content/dataset')
print(metrics)
# Out:
# Ultralytics 8.3.131 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n-cls summary (fused): 30 layers, 1,438,723 parameters, 0 gradients, 3.3 GFLOPs
# train: /content/dataset/train... found 428 images in 3 classes ✅
# val: /content/dataset/val... found 52 images in 3 classes ✅
# test: /content/dataset/test... found 56 images in 3 classes ✅
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 379.7±352.5 MB/s, size: 14.8 KB)
# val: Scanning /content/dataset/val... 52 images, 0 corrupt: 100%|██████████| 52/52 [00:00<?, ?it/s]
#                classes   top1_acc   top5_acc:   0%|          | 0/4 [00:00<?, ?it/s]
# WARNING ⚠️ ClassificationModel does not support 'augment=True' prediction. Reverting to single-scale prediction.
#                classes   top1_acc   top5_acc:  25%|██▌       | 1/4 [00:00<00:00,  4.78it/s]
# WARNING ⚠️ ClassificationModel does not support 'augment=True' prediction. Reverting to single-scale prediction.
# ...

# %% [markdown]
# # Training with Shearing, Translation

# %%
model = YOLO('yolov8n-cls.pt')
model.train(
    data="/content/dataset",
    epochs=100,
    imgsz=320,
    batch=16,
    augment=True,
    degrees=30,
    fliplr=0,
    flipud=0,
    scale=0,
    shear=5,
    translate=0.2
)
# Out:
# Ultralytics 8.3.131 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
metrics = model.val(data='/content/dataset')
print(metrics)
# Out:
# Ultralytics 8.3.131 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n-cls summary (fused): 30 layers, 1,438,723 parameters, 0 gradients, 3.3 GFLOPs
# train: /content/dataset/train... found 428 images in 3 classes ✅
# val: /content/dataset/val... found 52 images in 3 classes ✅
# test: /content/dataset/test... found 56 images in 3 classes ✅
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 276.4±286.2 MB/s, size: 14.8 KB)
# val: Scanning /content/dataset/val... 52 images, 0 corrupt: 100%|██████████| 52/52 [00:00<?, ?it/s]
#                classes   top1_acc   top5_acc:   0%|          | 0/4 [00:00<?, ?it/s]
# WARNING ⚠️ ClassificationModel does not support 'augment=True' prediction. Reverting to single-scale prediction.
#                classes   top1_acc   top5_acc:  25%|██▌       | 1/4 [00:00<00:00,  4.18it/s]
# WARNING ⚠️ ClassificationModel does not support 'augment=True' prediction. Reverting to single-scale prediction.
# ...

# %% [markdown]
# # Export

# %%
import shutil

folder_path = "/content/runs"
zip_path = "/content/runs.zip"

shutil.make_archive(zip_path.replace(".zip", ""), 'zip', folder_path)

from google.colab import files
files.download(zip_path)
